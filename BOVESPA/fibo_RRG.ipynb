# %%
import datetime
import pandas as pd
from pandas_datareader import data
import numpy as np
from datetime import timedelta
#pip install pandas-datareader
import time
start=time.time()
hoje =  (datetime.datetime.today() - timedelta(days=16))      ##datetime.datetime.today()

inicio=(datetime.datetime.today() - timedelta(days=320))
data1=str(hoje.year)+'-'+str(hoje.month)+'-'+str(hoje.day)
hoje
# Out:
# datetime.datetime(2021, 2, 12, 17, 13, 45, 717596)

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Nov 15 11:49:27 2020

@author: theone
"""
import datetime
import pandas as pd
from pandas_datareader import data
import numpy as np
from datetime import timedelta
#pip install pandas-datareader
import time
start=time.time()

inicio=(datetime.datetime.today() - timedelta(days=320))#.strftime("%Y,%m,%d")

def RSI(dataset, n=14):
    delta = dataset.diff()
    #-----------
    dUp, dDown = delta.copy(), delta.copy()
    dUp[dUp < 0] = 0
    dDown[dDown > 0] = 0

    RolUp = pd.Series(dUp).rolling(window=n).mean()
    RolDown = pd.Series(dDown).rolling(window=n).mean().abs()
    RS = RolUp / RolDown
    rsi= 100.0 - (100.0 / (1.0 + RS))
    return rsi



def predict(acao):

    try:
        if acao=='USDBRL=X' or acao=='^BVSP' or acao=='GC=F' or acao=='CL=F' or acao=='ZS=F' or acao=='SI=F' or acao=='^DJI' or acao=='^IXIC':
            stock=acao
        else:
            stock = '{}.SA'.format(acao)
        source = 'yahoo'
        
        # Set date range (Google went public August 19, 2004)
        start =inicio#datetime.datetime(2020, 3, 1)
        end = hoje
        
        # Collect Google stock data
        goog_df = data.DataReader(stock, source, start, end)
        
        dataset = goog_df['Adj Close']

        #goog_df['Adj Close'].plot(kind='line', grid=True, title='{} Adjusted Closes, IPO through 2016'.format(stock))
        
        ## FIBO DINAMICO
        max_periodo=np.max(dataset[-144:])
        min_periodo=np.min(dataset[-144:])
        
        diff=max_periodo-min_periodo
        
        primeiro_fibo=min_periodo+0.328*diff
        segundo_fibo=min_periodo+0.618*diff
        meio=min_periodo+0.5*diff
        media_verde=np.mean(dataset[-3:])
        media_vermelha=np.mean(dataset[-13:])
        
        tendencia=media_verde-media_vermelha
        print(acao,tendencia)
        fibo_superior=dataset[-1]-segundo_fibo
        #limiar_superior=(max_periodo-segundo_fibo)
        #limiar_inferior=(primeiro_fibo-min_periodo)
        
        
        fibo_inferior=dataset[-1]-primeiro_fibo
        
        rsi=RSI(goog_df.Close)[-1]

        if tendencia>0 and fibo_inferior>0 and  dataset[-1]>dataset[-5] and dataset[-1]>primeiro_fibo:
            output='buy'
            print('buy')
        elif tendencia<0 and fibo_superior<0 and dataset[-1]<dataset[-5] and dataset[-1]<segundo_fibo:
            output='short'
            print('short')
        else:
            output='wait'
            print('wait')
        close=dataset[-1]
        ganho=(max_periodo/segundo_fibo)-1
        diferenca=media_verde-media_vermelha
        oportunidade=dataset[-1]-meio
        momentum=((dataset[-1]-dataset[-11])/dataset[-1])*1000
    except Exception as e:
        print(e)
        output='NA'
        close='NA'
        ganho='NA'
        diferenca='NA'
        oportunidade='NA'
        rsi='NA'
        momentum='NA'
    return output, close,ganho,diferenca,oportunidade, rsi, momentum

df=pd.read_csv('Lista_Acoes_Setor.csv',sep=',',header=0)
df.columns=['Sigla','Nome_Empresa','Setor']
df['Previsao']=np.zeros(df.shape[0])
df['Close']=np.zeros(df.shape[0])
df['Potencial']=np.zeros(df.shape[0])
df['MM_diff']=np.zeros(df.shape[0])
df['eixo_xx']=np.zeros(df.shape[0])
df['Data']=np.zeros(df.shape[0])
df['IFR']=np.zeros(df.shape[0])
df['Momentum']=np.zeros(df.shape[0])

# %%
for i in range(0,df.shape[0]):
    try:#df.shape[0]):
        prev=predict(df.iloc[i,0])
        df['Previsao'].iloc[i]=prev[0]
        df['Close'].iloc[i]=prev[1]
        df['Potencial'].iloc[i]=prev[2]
        df['MM_diff'].iloc[i]=prev[3]
        df['eixo_xx'].iloc[i]=prev[4]
        df['IFR'].iloc[i]=prev[5]
        df['Data'].iloc[i]=data1
        df['Momentum'].iloc[i]=prev[6]
    except:
        pass
df['Mood']=np.zeros(df.shape[0])

for i in range(0,df.shape[0]):
    if df['Previsao'][i]=='buy':
        df['Mood'][i]=1
    if df['Previsao'][i]=='short':
        df['Mood'][i]=-1
    if df['Previsao'][i]=='wait':
        df['Mood'][i]=0
    if df['Previsao'][i]=='NA':
        df['Mood'][i]=0
# Out:
# 5864674
# short
# BEES4 -0.060242200509095234
# wait
# BERK34 1.2974343911195376
# buy
# BGIP3 -0.6884610102726896
# short
# BGIP4 -0.3446156428410454
# short
# BIDI11 2.6984612880608836
# wait
# BIDI3 0.922820458045372
# wait
# BIDI4 1.3730759253868712
# wait
# BIIB34 3.658972324469147
# wait
# BIOM3 -0.4497435643122749
# short
# BKBR3 0.21589746230687723
# buy
# BLAK34 -1.7205028044871824
# wait
# BMEB3 0.06468058855105951
# buy
# BMEB4 0.7423041906112289
# buy
# BMIN3 0.6997434175931474
# wait
# BMIN4 1.0469227815285684
# buy
# BMKS3 5.438718746869995
# buy
# BMLC11B 0.0
# wait
# BMYB34 -8.867948091947142
# wait
# BNBR3 -0.16769389617137165
# short
# BNFS11 -1.3871788611778868
# short
# BOAC34 1.622820438482826
# buy
# BOBR4 -0.030512791413527474
# short
# BOEI34 33.28718449519238
# buy
# BONY34 1.5812812218299257
# wait
# BOVA11 0.5294880011142737
# wait
# BOVV11 0.5692310822315818
# wait
# BOXP34 0.8494873046875
# wait
# BPAC11 4.963334108010315
# wait
# BPAC3 0.6725634061373214
# buy
# BPAC5 2.604358770908455
# wait
# BPAN4 1.3202565022003956
# wait
# BPFF11 0.14461556459083624
# wait
# BRAP3 -0.9346156976161808
# short
# BRAP4 -0.5715387784517745
# wait
# BRAX11 0.6084618201622618
# wait
# BRCR11 -1.011539948292267
# short
# BRDT3 -0.4915385613074683
# wait
# BRFS3 0.8089741437863083
# buy
# BRGE11 -3.5045814025096416
# short
# BRGE12 0.07794871697059058
# wait
# BRGE3 -0.40717956347343254
# short
# BRGE6 -0.8714711115910454
# wait
# BRGE8 0.6791311166225338
# buy
# BRIV3 -0.6811512922629319
# short
# BRIV4 -0.010204950968423887
# short
# BRKM3 1.5717949989514501
# buy
# BRKM5 1.9294870816744307
# buy
# BRML3 -0.2235896526238843
# short
# BRPR3 -0.14897434528057474
# short
# BRSR3 -0.117435846573267
# short
# BRSR5 0.041794703556941926
# wait
# BRSR6 -0.11615405938564116
# short
# BSEV3 -0.33871790078970143
# wait
# BSLI3 -1.8489732986841503
# short
# BSLI4 3.7502565628443065
# wait
# BTCR11 -0.0735888358874206
# wait
# BTOW3 -0.7148703550681148
# wait
# BTTL3 0.047179222106933594
# wait
# BZLI11 -0.06641008915045354
# short
# 'Date'
# CAML3 0.07589758359468846
# wait
# CARD3 0.24230795640211866
# buy
# CARE11 -0.010769220498891952
# short
# CATP34 1.8631877410106057
# buy
# CBEE3 -0.3179489526993198
# short
# CBOP11 1.035382979955429
# wait
# CCPR3 -0.2989743795150357
# short
# CCRO3 -0.06564096304086497
# wait
# No data fetched for symbol CCXC3.SA using YahooDailyReader
# CEBR3 1.9694894643930354
# wait
# CEBR5 -1.321288279998015
# wait
# CEBR6 4.444360977564116
# wait
# CEDO3 -0.12205128792004594
# short
# CEDO4 -0.03794868175800037
# wait
# CEEB3 -0.08230737539437882
# wait
# CEGR3 0.0
# wait
# No data fetched for symbol CELP3.SA using YahooDailyReader
# No data fetched for symbol CELP5.SA using YahooDailyReader
# No data fetched for symbol CELP6.SA using YahooDailyReader
# No data fetched for symbol CELP7.SA using YahooDailyReader
# CEOC11 0.22589561266777025
# wait
# CEPE5 0.0
# wait
# CEPE6 -1.6538461538461533
# wait
# CESP3 0.45564137972318264
# wait
# CESP5 0.6382054059933395
# buy
# CESP6 0.045897361559745775
# wait
# CGAS3 0.00968385354067891
# wait
# CGAS5 -1.3510061410757146
# wait
# CGRA3 -0.5566670344426115
# wait
# CGRA4 -1.3828204228327792
# short
# No data fetched for symbol CHKE34.SA using YahooDailyReader
# CHVX34 1.45758995643029
# buy
# CIEL3 -0.24139802883832884
# short
# No data fetched for symbol CLGN34.SA using YahooDailyReader
# CLSC4 -0.7333324138934785
# short
# CMCS34 1.5279483306102293
# buy
# CMIG3 -0.5184613741361161
# wait
# CMIG4 -0.3064104715983067
# wait
# CNES11 0.0
# wait
# CNTO3 -1.3684612176357192
# short
# COCA34 0.6685905456542969
# buy
# COCE3 -2.903077345628006
# short
# COCE5 -1.124359130859375
# short
# COLG34 -0.3459334740271913
# short
# COPH34 4.075640262701576
# wait
# COTY34 -0.39512829902844615
# wait
# COWC34 -0.44128202780699155
# short
# CPFE3 0.9520508203750992
# wait
# CPLE3 0.5833333333333286
# wait
# CPLE6 0.04564099434095681
# wait
# No data fetched for symbol CPRE3.SA using YahooDailyReader
# No data fetched for symbol CPTS11B.SA using YahooDailyReader
# CRDE3 -2.398461415217472
# short
# CRFB3 0.3828205695519067
# buy
# CRFF11 1.935127062675278
# buy
# CRIV3 -0.49461528582450676
# short
# CRIV4 -0.008014788994421984
# wait
# CRPG3 0.6138475858248214
# wait
# CRPG5 1.487180074055992
# buy
# CRPG6 1.1010263883150557
# buy
# CSAB3 0.0
# wait
# CSAB4 -0.4761543273925781
# short
# CSAN3 5.264614594288361
# buy
# CSCO34 0.7164105146359177
# wait
# CSMG3 0.056923010410407926
# buy
# CSNA3 0.7571798471304092
# wait
# CSRN3 0.14999983860896293
# wait
# CSRN5 0.688974453852726
# wait
# CSRN6 0.057693041287937064
# wait
# CTGP34 1.430256476769081
# buy
# CTKA3 0.06512808188413999
# wait
# CTKA4 -0.0066667214418068
# short
# CTNM3 -0.3707693051069221
# short
# CTNM4 -0.1769230182354269
# short
# CTSA3 -0.07000011664170502
# short
# CTSA4 0.0012820500593919704
# wait
# CTSH34 -9.227327786959108
# wait
# CTXT11 -0.7761538578913729
# short
# CVCB3 -0.1094874846629601
# wait
# CVSH34 1.6323066124549257
# buy
# CXCE11B -0.7961550981570582
# wait
# CXRI11 -2.1566651173126985
# wait
# CXTL11 -1.3853853665865472
# short
# CYRE3 0.6130770169771651
# wait
# DASA3 -9.382308959960938
# wait
# DEAI34 11.981279813326324
# buy
# DHER34 0.669487586388243
# buy
# DIRR3 0.01743588080772973
# wait
# DISB34 3.3333342136480866
# wait
# DIVO11 0.015384576259521054
# wait
# DMAC11 -3.014614789913864
# wait
# DMMO3 -0.06282051098652375
# short
# DOHL4 -0.21256411381256957
# short
# DOMC11 0.0
# wait
# DRIT11B -5.739486498710434
# short
# DTCY3 -0.060769081115722656
# short
# DTEX3 -1.1819375845102158
# short
# DUKB34 -4.741027049529237
# short
# EALT3 -0.5984614934676724
# short
# EALT4 -0.03410274554521653
# short
# EBAY34 5.460000845102172
# wait
# ECOO11 -0.288974077273636
# wait
# ECOR3 -0.15282039153270333
# short
# ECPR3 0.0
# wait
# EDFO11B -0.7728204971704713
# short
# EDGA11 0.179743253267727
# wait
# EEEL3 0.0
# wait
# EGIE3 0.906666975754959
# buy
# EKTR4 0.4566665551601332
# buy
# No data fetched for symbol ELEK3.SA using YahooDailyReader
# No data fetched for symbol ELEK4.SA using YahooDailyReader
# ELET3 0.39796095628004835
# buy
# ELET6 0.11140911395733255
# wait
# No data fetched for symbol ELPL3.SA using YahooDailyReader
# EMAE4 0.16871887598282598
# buy
# EMBR3 0.4725642082018737
# buy
# ENAT3 0.5066664524567432
# buy
# ENBR3 -0.5135897122896651
# short
# ENEV3 1.5730775686410823
# wait
# ENGI11 0.12846159323667905
# buy
# ENGI3 0.7774356450790023
# buy
# ENGI4 -0.11666673269027328
# short
# No data fetched for symbol ENMA3B.SA using YahooDailyReader
# ENMT3 -0.0256406343900224
# wait
# ENMT4 0.0
# wait
# EQTL3 0.3199996459178429
# buy
# No data fetched for symbol ESTC3.SA using YahooDailyReader
# ESTR4 -0.7094869858179322
# short
# ETER3 -0.24615390484149557
# short
# EUCA3 -0.4751276847643702
# wait
# EUCA4 -0.036666539999155034
# wait
# EURO11 2.867178892477966
# wait
# EVEN3 -0.12487152295234871
# short
# EXXO34 2.5164080888797145
# wait
# EZTC3 -1.8382047995542834
# short
# 'Date'
# FAMB11B -30.233846028645758
# short
# FBOK34 0.492052029340698
# wait
# FCFL11 0.33615366617839015
# wait
# FCXO34 8.735895401392241
# wait
# FDMO34 1.3987177335298995
# buy
# FDXB34 43.21230218349365
# buy
# FESA3 2.3320516928648303
# wait
# FESA4 0.6371795458671379
# wait
# FEXC11 0.0
# wait
# FFCI11 0.0
# wait
# FHER3 -0.082051271047348
# wait
# FIGS11 -0.239230424929886
# wait
# FIIB11 -2.23437186999206
# wait
# FIIP11B -0.03871937287158289
# wait
# FIND11 -1.1482052925305481
# wait
# FIVN11 -0.08794868909395692
# wait
# FIXX11 0.0
# wait
# No data fetched for symbol FJTA3.SA using YahooDailyReader
# No data fetched for symbol FJTA4.SA using YahooDailyReader
# FLMA11 -0.008205120380108344
# short
# 'Date'
# FLRY3 0.28282043261405576
# buy
# FMOF11 -1.101537068684891
# short
# FMXB34 0.1540973369891958
# wait
# FOFT11 0.0
# wait
# FPAB11 -0.82025146484375
# short
# FRAS3 0.6623078370705642
# buy
# FRIO3 -3.026154151329621
# wait
# FRTA3 -0.09641029895880227
# short
# FSLR34 -1.4971775152744158
# wait
# No data fetched for symbol FVBI11.SA using YahooDailyReader
# FVPQ11 -1.2525669978215035
# short
# No data fetched for symbol GBIO33.SA using YahooDailyReader
# GEOO34 0.7499998043745038
# wait
# GEPA3 -0.314615983229416
# wait
# GEPA4 -0.2438456217447893
# wait
# GFSA3 0.45410260176047323
# wait
# GGBR3 0.04641034052922066
# wait
# GGBR4 0.1961539341853218
# buy
# GGRC11 1.1338461851462114
# wait
# GILD34 0.665387275891419
# wait
# GMCO34 0.2971793932792366
# wait
# GNDI3 -1.518205887232071
# wait
# GOAU3 0.038461342836038526
# wait
# GOAU4 0.07589760804787637
# buy
# GOGL34 2.7525668021960144
# wait
# GOGL35 2.9702555338541714
# wait
# GOLL4 -0.47999998239370356
# wait
# GOVE11 0.24153821896284455
# wait
# GPAR3 -4.0169219970703125
# short
# GPCP3 -0.42897459176870356
# wait
# GPIV33 -0.02564103175432253
# short
# GRLV11 0.0
# wait
# GRND3 -0.02461532446054271
# wait
# GSFI11 0.017948700831486697
# buy
# GSGI34 6.677177624824708
# buy
# GSHP3 -0.8484620314377977
# short
# GTWR11 0.5956397423377382
# wait
# GUAR3 -0.40923067239614674
# short
# HAGA3 0.018717967546903136
# wait
# HAGA4 0.0787179653461163
# buy
# HALI34 5.404103792630707
# buy
# HAPV3 -0.2612817226312103
# wait
# HBOR3 -0.28307667756691934
# short
# HBTS5 0.4430766472449683
# buy
# No data fetched for symbol HBTT11.SA using YahooDailyReader
# HCRI11 0.0
# wait
# HCTR11 -4.15717335236377
# wait
# HETA4 -0.1664103483542405
# wait
# HFOF11 0.057434668907745845
# wait
# HGBS11 0.1525605030548718
# buy
# HGCR11 0.6082049638797145
# buy
# HGLG11 -0.5030783628805864
# wait
# HGPO11 0.3858963403946518
# wait
# HGRE11 0.3584641676682736
# buy
# HGRU11 0.8897454677483836
# wait
# HGTX3 -0.4158975161038896
# short
# HMOC11 -0.4538472493489678
# wait
# HOME34 0.047180567032256704
# wait
# HONB34 7.758516751802972
# wait
# HOOT4 -0.00333331181452845
# short
# HPQB34 8.475381704477172
# buy
# HSHY34 -0.8338576096754764
# wait
# HTMX11 1.4205134465144198
# buy
# HUSC11 0.2776954846504225
# buy
# HYPE3 0.2284612411107716
# buy
# IBMB34 -1.3846138196113316
# short
# 'Date'
# No data fetched for symbol IDNT3.SA using YahooDailyReader
# IDVL3 -0.1033333234297924
# short
# IDVL4 -0.00999997212336634
# short
# IGBR3 2.062051112835224
# wait
# IGTA3 -0.3594869955992053
# short
# INEP3 2.401538702157829
# wait
# INEP4 2.4189740205422403
# wait
# IRBR3 -0.36615383930695433
# short
# IRDM11 1.7241038787059324
# wait
# ISUS11 0.256154280442459
# buy
# ITLC34 2.0735905965169295
# wait
# ITSA3 -0.1876922754141006
# short
# ITSA4 -0.10461526039319047
# wait
# ITUB3 -0.4983289180657806
# short
# ITUB4 -0.5070363069191934
# wait
# IVVB11 0.0
# wait
# No data fetched for symbol JBDU11.SA using YahooDailyReader
# No data fetched for symbol JBDU12.SA using YahooDailyReader
# JBDU3 -0.0007692300356350046
# short
# JBDU4 -0.007179532295618296
# short
# JBSS3 1.1456411312787935
# buy
# JFEN3 0.0
# wait
# JHSF3 -0.2369231199606876
# short
# JNJB34 0.3658972520094679
# buy
# JOPA3 -0.80179576384716
# short
# JOPA4 0.0
# wait
# JPMC34 2.0635906121669763
# wait
# JPSA3 -0.19435882568359375
# wait
# JRDM11 0.0
# wait
# JSLG3 -1.2620517535087394
# wait
# JSRE11 -1.165896684695511
# short
# KEPL3 4.643589704464645
# buy
# KFOF11 0.1458971072465971
# wait
# KHCB34 1.0948719122471005
# buy
# KLBN11 -0.17000002738756947
# wait
# KLBN3 0.03076931146475026
# buy
# KLBN4 -0.022820607209816934
# wait
# KMBB34 -4.320512820512818
# short
# KNCR11 0.07204985007261655
# buy
# KNHY11 0.8451272035256352
# buy
# KNIP11 1.2610266269781647
# buy
# KNRE11 -0.0420513275342107
# wait
# KNRI11 0.224615635016022
# buy
# No data fetched for symbol KROT3.SA using YahooDailyReader
# LAME3 -0.34512818165314485
# short
# LAME4 -0.3066669366298598
# wait
# LCAM3 -0.4205125172932931
# wait
# LEVE3 -0.2474358876546212
# short
# LIGT3 -0.461025629288109
# short
# LILY34 -1.3735868013822028
# wait
# LINX3 0.495897244184448
# buy
# LIPR3 -2.5030775803786014
# wait
# No data fetched for symbol LIQO3.SA using YahooDailyReader
# LLIS3 -0.10384623209635446
# short
# LMTB34 31.911777594150635
# wait
# LOFT11B -0.28435912499060834
# wait
# LOGG3 -1.1625632261618577
# short
# LOGN3 -0.2666664857130776
# short
# LPSB3 -0.28615383001474193
# short
# LREN3 -1.499743632781204
# short
# LUPA3 -0.06282050792987537
# short
# LUXM4 -0.0323075514573361
# wait
# LVBI11 0.8528213500976562
# wait
# MACY34 -1.1223078018579713
# wait
# MALL11 -0.9966655633388513
# wait
# MAPT4 0.0
# wait
# MATB11 1.5379483149601896
# buy
# 'Date'
# MBRF11 -27.387437086838986
# short
# MCDC34 0.6000004303760988
# wait
# MDIA3 -0.07948694473657625
# short
# MDLZ34 -1.5030728853665778
# wait
# MDTC34 5.822821201422244
# buy
# MEAL3 -0.05820514605595495
# wait
# No data fetched for symbol MEND5.SA using YahooDailyReader
# 'Date'
# METB34 22.969739082532044
# buy
# MFII11 -0.5376896002353817
# wait
# MGEL4 0.018717863620857145
# buy
# MGFF11 1.3243574484800718
# buy
# MGLU3 -0.058461800599708624
# wait
# MILS3 -0.003589740166296984
# short
# MMMC34 -0.6751282520783093
# wait
# MMXM3 0.39461571130997086
# wait
# MNDL3 0.4907693129319419
# buy
# MNPR3 -0.2515383378053322
# wait
# MOAR3 0.6028188069661553
# wait
# MOSC34 0.4638472336989139
# buy
# MOVI3 -0.3884616264930152
# short
# MRCK34 -1.2156414129795223
# short
# MRFG3 0.5446152809338685
# buy
# MRVE3 -0.23051305917593012
# wait
# MSBR34 2.6053836529071503
# buy
# MSCD34 0.6073565360827331
# buy
# MSFT34 0.5237107888246229
# wait
# MSPA3 0.0
# wait
# MTIG4 1.789744450495796
# buy
# MTSA3 0.0
# wait
# MTSA4 -0.20153803703112416
# wait
# MULT3 -0.19384604233961866
# short
# MWET4 -0.19666672975589083
# short
# MXRF11 0.08999988360282707
# buy
# MYPK3 -0.11256411136725042
# wait
# No data fetched for symbol NAFG3.SA using YahooDailyReader
# No data fetched for symbol NAFG4.SA using YahooDailyReader
# No data fetched for symbol NATU3.SA using YahooDailyReader
# NEOE3 0.29820491106082514
# wait
# No data fetched for symbol NEOE3B.SA using YahooDailyReader
# NFLX34 0.7810255197378311
# wait
# NIKE34 1.3152413001427306
# wait
# NORD3 -1.0228207906087228
# wait
# NPAR11 2.0192295954777535
# wait
# NSLU11 0.0
# wait
# NUTR3 0.0
# wait
# NVHO11 -0.9553846701597557
# wait
# ODPV3 -0.5425640741984044
# short
# OFSA3 0.5243589939215241
# wait
# OIBR3 -0.0864102657024679
# wait
# OIBR4 -0.09282048543294286
# short
# OMGE3 0.9733334076710207
# wait
# ONEF11 0.4269244854266958
# wait
# ORCL34 0.24256134033203125
# wait
# ORPD11 1.5676920964167778
# wait
# OSXB3 0.04641043834197234
# wait
# OUCY11 0.0
# wait
# OUFF11 1.2610240838466638
# buy
# OUJP11 -3.296923710749695
# short
# OULG11B 0.0
# wait
# PABY11 -0.14589747404440878
# short
# PARD3 -0.4784617790809058
# short
# PATC11 1.1620510786007543
# buy
# PATI3 -0.9292307144556347
# wait
# PATI4 1.8153842045710604
# buy
# PCAR3 5.1382037431765895
# buy
# No data fetched for symbol PCAR4.SA using YahooDailyReader
# PDGR3 -0.19999990707788662
# wait
# PEAB3 1.011539361415764
# buy
# PEAB4 -1.6441029279659958
# wait
# PEPB34 -1.1282056172688826
# short
# PETR3 -0.2817951104579848
# wait
# PETR4 -0.046410487248348176
# wait
# PFIZ34 -0.9637767107058792
# wait
# PFRM3 -0.16974373352833272
# short
# PGCO34 -0.5202563359187167
# short
# PHMO34 7.261541513296265
# buy
# PIBB11 0.9430749355218211
# wait
# PINE4 -0.017692309159499153
# wait
# PLAS3 -0.1523077549078522
# short
# PLRI11 0.4128210605719147
# buy
# PMAM3 0.004102340111366232
# wait
# PNVL3 -0.524359140640648
# short
# PNVL4 -0.3041027264717293
# short
# POMO3 -0.09564093443063593
# short
# POMO4 -0.1479487235729513
# short
# PORD11 0.2756394606370236
# wait
# POSI3 0.11410266925127122
# wait
# PPLA11 -0.08153812701885599
# short
# PQDP11 -23.746156350160618
# short
# PRIO3 2.8117951613206174
# wait
# PRSV11 -0.3723074106069646
# short
# PSSA3 -0.6689745585123674
# short
# PTBL3 0.03564110780373575
# wait
# PTNT3 -0.1592308191152716
# wait
# PTNT4 0.007948740934714316
# buy
# QCOM34 -3.0643574641301115
# wait
# QUAL3 0.41871784894894404
# buy
# RADL3 0.4284611726418497
# buy
# RAIL3 -0.8138465392283898
# short
# RANI3 0.08794867686736207
# wait
# No data fetched for symbol RANI4.SA using YahooDailyReader
# RAPT3 -0.2371794382731114
# wait
# RAPT4 -0.031025739816518794
# wait
# RBBV11 0.6423089443108978
# buy
# RBCB11 0.0
# wait
# RBDS11 -0.38641005295973585
# wait
# RBED11 -2.7741022354517213
# short
# RBGS11 -0.5269240354880296
# wait
# RBRD11 -1.3841028458032838
# short
# RBRF11 -0.5761548555814358
# short
# RBRP11 -0.322564540765228
# wait
# RBRR11 0.7776917677659299
# buy
# RBRY11 -0.8999983958708953
# wait
# RBVA11 -1.2969235151241918
# wait
# RBVO11 -0.5525635939378013
# short
# RCSL3 0.6043587831350479
# buy
# RCSL4 0.0023076839936087
# wait
# RDES11 0.0
# wait
# RDNI3 -0.2664101429474659
# short
# RDPD11 -1.1146152202899628
# short
# RECT11 0.2758988600510861
# buy
# REDE3 -0.006666696988618881
# wait
# REIT11 0.0
# wait
# RENT3 -0.30538500272311353
# wait
# RIGG34 0.3379490192119903
# wait
# RLOG3 1.1246150090144234
# buy
# RNDP11 17.076923076923094
# buy
# RNEW11 0.10538448431553071
# wait
# RNEW3 -0.0648718002514963
# short
# RNEW4 0.10538466160114002
# wait
# RNGO11 -0.8628221169496157
# short
# ROMI3 3.788974639696953
# buy
# ROST34 7.020250369340943
# wait
# RPAD3 -0.3133333646334133
# short
# RPAD5 -0.004795196728828444
# wait
# RPAD6 -0.1656409410329962
# short
# RPMG3 -0.006666623629056456
# wait
# RSID3 -0.1592307213025208
# wait
# RSUL4 2.084615854116578
# buy
# SAAG11 0.0
# wait
# SAIC11B 0.0
# wait
# SANB11 -0.132371560121193
# wait
# SANB3 -0.14387854551657853
# wait
# SANB4 0.03654162089030066
# buy
# SAPR11 -0.058717825473880936
# short
# SAPR3 0.0025640145326271124
# wait
# SAPR4 -0.016153922447791125
# short
# SBSP3 0.2779483306102293
# wait
# SBUB34 13.461278670873412
# wait
# SCAR3 -0.6992300962790452
# short
# SCHW34 2.026409638233673
# wait
# SCPF11 -0.0007694195478400445
# wait
# SDIL11 -0.784870441143326
# wait
# SEER3 -0.6841025230212097
# short
# SGPS3 -0.05102556179731277
# short
# SHOW3 -0.03307696489187384
# short
# SHPH11 16.237949469150635
# buy
# SHUL4 0.038461514008350406
# buy
# SLBG34 4.967174530029297
# buy
# SLCE3 3.7256405170147247
# buy
# SLED3 -0.028205101306621794
# short
# SLED4 -0.009230778767512438
# wait
# SMAL11 -0.1312807523287347
# wait
# SMLS3 0.3417953589023668
# buy
# SMTO3 2.780513274363983
# buy
# SNSY5 -0.083333308880146
# short
# SOND5 -342.7599997887245
# wait
# SOND6 -0.3923072814941406
# wait
# No data fetched for symbol SPRI3.SA using YahooDailyReader
# No data fetched for symbol SPRI5.SA using YahooDailyReader
# No data fetched for symbol SPRI6.SA using YahooDailyReader
# SPTW11 -1.5453835511818852
# short
# SPXI11 3.1838414118840035
# buy
# SQIA3 -0.21589782910469424
# short
# No data fetched for symbol SSBR3.SA using YahooDailyReader
# SSFO34 0.8361528836763839
# wait
# STBP3 0.18564108090522957
# buy
# SULA11 -1.398205879407051
# short
# SULA3 -0.5461539244040452
# short
# SULA4 -0.3387178763365135
# short
# SUZB3 4.320000281700715
# buy
# TAEE11 -0.24641095674954983
# wait
# TAEE3 -0.03589730385022172
# wait
# TAEE4 -0.0825641583173713
# wait
# TBOF11 0.0
# wait
# TCSA3 -0.1748717381403999
# short
# TECN3 0.17205129831265165
# buy
# TEKA3 -5.3538466233473585
# wait
# TEKA4 -0.31025637113130955
# wait
# TELB3 0.010769183819107297
# wait
# TELB4 -0.020513534545898438
# short
# TEND3 -1.2966665121225205
# short
# TESA3 2.4151283166347426
# buy
# TEXA34 1.648205879407051
# buy
# TFOF11 0.0
# wait
# TGAR11 0.0
# wait
# TGMA3 -1.5369230906168632
# short
# TGTB34 33.88795666816918
# buy
# THRA11 -0.9541031275040268
# wait
# TIET11 -0.4056415557861328
# wait
# TIET3 -0.07051288164578962
# short
# TIET4 -0.060000071158775814
# wait
# TIFF34 15.974593724959846
# buy
# No data fetched for symbol TIMP3.SA using YahooDailyReader
# TKNO4 1.6538461538461533
# buy
# TMOS34 -0.5633340493226697
# wait
# TOTS3 2.8761533590463486
# buy
# 'Date'
# No data fetched for symbol TOYB3.SA using YahooDailyReader
# No data fetched for symbol TOYB4.SA using YahooDailyReader
# TPIS3 -0.0051282430306458515
# short
# TRIS3 -0.4517948199541131
# short
# TRNT11 0.0
# wait
# TRPL3 -0.1756153106689453
# wait
# TRPL4 -0.7638153663048364
# wait
# No data fetched for symbol TRPN3.SA using YahooDailyReader
# TRVC34 0.0
# wait
# No data fetched for symbol TRXL11.SA using YahooDailyReader
# TSLA34 -5.483845637394836
# short
# TUPY3 -0.5923080444335938
# wait
# TWTR34 30.505385570037078
# buy
# TXRX4 -0.26820503137050444
# short
# UBSG34 1.9038438063401486
# buy
# UBSR11 0.0
# wait
# UCAS3 0.03974364354060267
# wait
# UGPA3 0.3135893895075874
# wait
# UNIP3 -0.085896418644829
# wait
# UNIP5 -0.6710262787647707
# wait
# UNIP6 -0.5497429676544954
# wait
# UPAC34 1.447210067357787
# buy
# UPSS34 0.501993326040413
# wait
# USBC34 2.7544853992951275
# buy
# USIM3 0.06641026032276542
# buy
# USIM5 0.44358977293356894
# buy
# USIM6 0.0
# wait
# USSX34 -4.262563265286957
# short
# No data fetched for symbol UTEC34.SA using YahooDailyReader
# VALE3 2.340511419834229
# wait
# VERZ34 -0.59743519318409
# short
# VGIR11 1.254103049253814
# buy
# VILG11 2.808205629006409
# buy
# VISA34 1.2058976980356064
# buy
# VISC11 0.5707690899188691
# buy
# VIVR3 -0.019743595367822886
# wait
# VIVT3 1.048719161596054
# buy
# No data fetched for symbol VIVT4.SA using YahooDailyReader
# VLID3 -0.17564103542230036
# short
# VLOE34 9.321540636894042
# buy
# VLOL11 2.490254915677582
# buy
# VOTS11 2.8089726765950473
# buy
# VRTA11 -0.14153563670622304
# wait
# VSHO11 -0.8251268435747221
# short
# VTLT11 -0.6117954743214256
# short
# VULC3 -0.19897426703037446
# wait
# VVAR3 -0.3379487013205491
# short
# WALM34 0.11897532145182055
# wait
# WEGE3 0.2266657902644198
# buy
# WFCO34 1.520769070356323
# wait
# WHRL3 0.058205017676720594
# buy
# WHRL4 0.02512826675023838
# buy
# WIZS3 -0.11564092147044658
# short
# WLMM3 -1.1774362417367783
# short
# WLMM4 0.7500000489063758
# buy
# WPLZ11 0.0
# wait
# WSON33 -0.5602564689440612
# wait
# WTSP11B -0.30794838147285475
# short
# XBOV11 0.6956405639648438
# wait
# XPCM11 -3.4576919751289523
# short
# XPHT11 -0.5982053707807466
# short
# 'Date'
# XPIN11 -0.0892279209234772
# wait
# XPLG11 0.6243581527318725
# wait
# XPML11 -0.35282135009765625
# wait
# XRXB34 3.1266680986453395
# buy
# XTED11 -0.014871768462351831
# wait

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     119                 else:
# --> 120                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     121             except Exception:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in reduction(values, axis, skipna, mask)
#     842         else:
# --> 843             result = getattr(values, meth)(axis)
#     844
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      33           initial=_NoValue, where=True):
# ---> 34     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      35
#
# TypeError: '<=' not supported between instances of 'float' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-020fde180cbf> in <module>
# ----> 1 np.min(df.IFR)
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2744     """
#    2745     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
# -> 2746                           keepdims=keepdims, initial=initial, where=where)
#    2747
#    2748
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      86                 return reduction(axis=axis, dtype=dtype, out=out, **passkwargs)
#      87             else:
# ---> 88                 return reduction(axis=axis, out=out, **passkwargs)
#      89
#      90     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11616             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   11617         return self._reduce(
# > 11618             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11619         )
#   11620
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4085                 )
#    4086             with np.errstate(all="ignore"):
# -> 4087                 return op(delegate, skipna=skipna, **kwds)
#    4088
#    4089         # TODO(EA) dispatch to Index
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     121             except Exception:
#     122                 try:
# --> 123                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     124                 except ValueError as e:
#     125                     # we want to transform an object array
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in reduction(values, axis, skipna, mask)
#     841                 result = np.nan
#     842         else:
# --> 843             result = getattr(values, meth)(axis)
#     844
#     845         result = _wrap_results(result, dtype, fill_value)
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      32 def _amin(a, axis=None, out=None, keepdims=False,
#      33           initial=_NoValue, where=True):
# ---> 34     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      35
#      36 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: '<=' not supported between instances of 'float' and 'str'

# %%
def norm(x):
    return (x-np.min(x))/(np.max(x)-np.min(x))

for i in range(0,df.shape[0]):
    if df.Previsao[i]=='buy':
        df['Mood'][i]=1
    elif df.Previsao[i]=='short':
        df['Mood'][i]=-1
    else:
        df['Mood'][i]=0

# %%
df=df[df.Potencial!='NA']

# %%
df['Y_ForçaMM']=norm(df.Potencial)
df['X_Probabilidade_Fibo']=norm(df.eixo_xx)
df['Momentum']
# Out:
# 0      38.0313
# 1      1.45773
# 2      15.4815
# 3      122.247
# 4     -13.5292
#         ...
# 691   -1.82608
# 692    6.54661
# 693   -11.4538
# 694    87.6984
# 695    -2.8169
# Name: Momentum, Length: 644, dtype: object

# %%
df['Momentum']-float(df[df['Sigla']=='^BVSP']['Momentum'])
# Out:
# 0      11.9307
# 1     -24.6429
# 2     -10.6191
# 3      96.1459
# 4     -39.6298
#         ...
# 691   -27.9267
# 692    -19.554
# 693   -37.5544
# 694    61.5978
# 695   -28.9175
# Name: Momentum, Length: 644, dtype: object

# %%
#df['Momentum']=df['Momentum']-float(df[df['Sigla']=='^BVSP']['Momentum'])
df['IFR']=df['IFR']-float(df[df['Sigla']=='^BVSP']['IFR'])
df['IFR']
# Out:
# 0      -3.38146
# 1      0.462748
# 2       2.48257
# 3       30.0576
# 4      -16.3116
#          ...
# 691     -3.6238
# 692     2.85691
# 693    -24.2699
# 694    -1.74714
# 695    -5.19267
# Name: IFR, Length: 644, dtype: object

# %%
df['Momentum']=df['Momentum']/280
df['Momentum']
# Out:
# 0        0.135826
# 1      0.00520616
# 2        0.055291
# 3        0.436595
# 4      -0.0483185
#           ...
# 691   -0.00652171
# 692     0.0233807
# 693    -0.0409063
# 694      0.313209
# 695    -0.0100604
# Name: Momentum, Length: 644, dtype: object

# %%
df[['Sigla', 'Nome_Empresa', 'Previsao', 'Close', 'Potencial', 'MM_diff',
       'eixo_xx', 'Mood', 'Y_ForçaMM', 'X_Probabilidade_Fibo','Data','Setor','IFR','Momentum']].to_csv('dataframe_PowerBI.csv',sep=',',index=False,columns=df.columns)

# %%
import datetime

import pandas as pd
import pytz
import numpy as np
# Construct a BigQuery client object.

# TODO(developer): Set table_id to the ID of the table to create.
# table_id = "your-project.your_dataset.your_table_name"


dataframe = pd.read_csv('dataframe_PowerBI.csv',sep=',',header=0)

dataframe=dataframe.dropna(axis=0)
dataframe.columns
dataframe
# Out:
#         Sigla    Nome_Empresa        Setor Previsao        Close  Potencial  \
# 0       PETZ3            PETZ      Animais      buy    22.350000   0.171371
# 1        ZS=F            SOJA  Commodities     wait  1372.000000   0.177273
# 2        SI=F           PRATA  Commodities     wait    27.323000   0.144442
# 3        CL=F    PETRÓLEO CRU  Commodities      buy    59.470001   0.179393
# 4    USDBRL=X           DOLAR        Moeda    short     5.365400   0.052437
# ..        ...             ...          ...      ...          ...        ...
# 639    XPIN11     FII XP INDL         DBRs     wait   115.000000   0.024650
# 640    XPLG11      FII XP LOG         DBRs     wait   122.199997   0.046620
# 641    XPML11    FII XP MALLS         DBRs     wait   113.500000   0.073550
# 642    XRXB34  XEROX CORP DRN         DBRs      buy   126.000000   0.170539
# 643    XTED11    FII TRXE COR         DBRs     wait     7.100000   0.071768
#
#       MM_diff     eixo_xx       Data        IFR  Momentum  Mood  Y_ForçaMM  \
# 0    0.415898    4.037278  2021-2-12  -3.381457  0.135826   1.0   0.280200
# 1   -5.615385  218.625000  2021-2-12   0.462748  0.005206   0.0   0.289851
# 2    0.185795    2.781500  2021-2-12   2.482567  0.055291   0.0   0.236170
# 3    2.858976   11.840000  2021-2-12  30.057641  0.436595   1.0   0.293317
# 4   -0.016702   -0.035600  2021-2-12 -16.311648 -0.048318  -1.0   0.085737
# ..        ...         ...        ...        ...       ...   ...        ...
# 639 -0.089228   -0.339996  2021-2-12  -3.623802 -0.006522   0.0   0.040305
# 640  0.624358   -5.400002  2021-2-12   2.856906  0.023381   0.0   0.076226
# 641 -0.352821    4.270000  2021-2-12 -24.269896 -0.040906   0.0   0.120258
# 642  3.126668   22.813953  2021-2-12  -1.747136  0.313209   1.0   0.278841
# 643 -0.014872   -0.655000  2021-2-12  -5.192671 -0.010060   0.0   0.117345
#
#      X_Probabilidade_Fibo
# 0                0.456382
# 1                0.468306
# 2                0.456312
# 3                0.456816
# 4                0.456156
# ..                    ...
# 639              0.456139
# 640              0.455858
# 641              0.456395
# 642              0.457425
# 643              0.456121
#
# [603 rows x 14 columns]

# %%
dataframe['Data'] = dataframe['Data'].astype('datetime64[ns]')

# %%
dataframe.columns
# Out:
# Index(['Sigla', 'Nome_Empresa', 'Setor', 'Previsao', 'Close', 'Potencial',
#        'MM_diff', 'eixo_xx', 'Data', 'IFR', 'Momentum', 'Mood', 'Y_ForçaMM',
#        'X_Probabilidade_Fibo'],
#       dtype='object')

# %%
dataframe.columns=['Sigla', 'Nome_Empresa', 'Setor', 'Previsao', 'Close', 'Potencial',
       'MM_diff', 'eixo_xx', 'Data', 'IFR', 'Momentum', 'Mood','Y_For__aMM',
       'X_Probabilidade_Fibo']
dataframe=dataframe[['Sigla', 'Nome_Empresa', 'Previsao', 'Close', 'Potencial', 'MM_diff',
       'eixo_xx',  'Momentum', 'Y_For__aMM', 'X_Probabilidade_Fibo','Data','Setor','IFR','Mood']]
dataframe
# Out:
#         Sigla    Nome_Empresa Previsao        Close  Potencial   MM_diff  \
# 0       PETZ3            PETZ      buy    22.350000   0.171371  0.415898
# 1        ZS=F            SOJA     wait  1372.000000   0.177273 -5.615385
# 2        SI=F           PRATA     wait    27.323000   0.144442  0.185795
# 3        CL=F    PETRÓLEO CRU      buy    59.470001   0.179393  2.858976
# 4    USDBRL=X           DOLAR    short     5.365400   0.052437 -0.016702
# ..        ...             ...      ...          ...        ...       ...
# 639    XPIN11     FII XP INDL     wait   115.000000   0.024650 -0.089228
# 640    XPLG11      FII XP LOG     wait   122.199997   0.046620  0.624358
# 641    XPML11    FII XP MALLS     wait   113.500000   0.073550 -0.352821
# 642    XRXB34  XEROX CORP DRN      buy   126.000000   0.170539  3.126668
# 643    XTED11    FII TRXE COR     wait     7.100000   0.071768 -0.014872
#
#         eixo_xx  Momentum  Y_For__aMM  X_Probabilidade_Fibo       Data  \
# 0      4.037278  0.135826    0.280200              0.456382 2021-02-12
# 1    218.625000  0.005206    0.289851              0.468306 2021-02-12
# 2      2.781500  0.055291    0.236170              0.456312 2021-02-12
# 3     11.840000  0.436595    0.293317              0.456816 2021-02-12
# 4     -0.035600 -0.048318    0.085737              0.456156 2021-02-12
# ..          ...       ...         ...                   ...        ...
# 639   -0.339996 -0.006522    0.040305              0.456139 2021-02-12
# 640   -5.400002  0.023381    0.076226              0.455858 2021-02-12
# 641    4.270000 -0.040906    0.120258              0.456395 2021-02-12
# 642   22.813953  0.313209    0.278841              0.457425 2021-02-12
# 643   -0.655000 -0.010060    0.117345              0.456121 2021-02-12
#
#            Setor        IFR  Mood
# 0        Animais  -3.381457   1.0
# 1    Commodities   0.462748   0.0
# 2    Commodities   2.482567   0.0
# 3    Commodities  30.057641   1.0
# 4          Moeda -16.311648  -1.0
# ..           ...        ...   ...
# 639         DBRs  -3.623802   0.0
# 640         DBRs   2.856906   0.0
# 641         DBRs -24.269896   0.0
# 642         DBRs  -1.747136   1.0
# 643         DBRs  -5.192671   0.0
#
# [603 rows x 14 columns]

# %%
from google.cloud import bigquery
client = bigquery.Client()

job_config = bigquery.LoadJobConfig(
    # Specify a (partial) schema. All columns are always written to the
    # table. The schema is used to assist in data type definitions.
    schema=[
        # Specify the type of columns whose type cannot be auto-detected. For
        # example the "title" column uses pandas dtype "object", so its
        # data type is ambiguous.
        bigquery.SchemaField("Sigla", bigquery.enums.SqlTypeNames.STRING),
        # Indexes are written if included in the schema by name.
        bigquery.SchemaField("Nome_Empresa", bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField("Previsao", bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField("Close", bigquery.enums.SqlTypeNames.FLOAT),
        bigquery.SchemaField("Potencial", bigquery.enums.SqlTypeNames.FLOAT),
        bigquery.SchemaField("MM_diff", bigquery.enums.SqlTypeNames.FLOAT),
        bigquery.SchemaField("eixo_xx", bigquery.enums.SqlTypeNames.FLOAT),
        bigquery.SchemaField("Mood", bigquery.enums.SqlTypeNames.INTEGER),
        bigquery.SchemaField("Y_For__aMM", bigquery.enums.SqlTypeNames.FLOAT),
        bigquery.SchemaField("X_Probabilidade_Fibo", bigquery.enums.SqlTypeNames.FLOAT),
        bigquery.SchemaField("Data", bigquery.enums.SqlTypeNames.DATE),
        bigquery.SchemaField("Momentum", bigquery.enums.SqlTypeNames.FLOAT),
        bigquery.SchemaField("Setor", bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField("IFR", bigquery.enums.SqlTypeNames.FLOAT),
    ],
    # Optionally, set the write disposition. BigQuery appends loaded rows
    # to an existing table by default, but with WRITE_TRUNCATE write
    # disposition it replaces the table with the loaded data.
    write_disposition="WRITE_APPEND",
)

job = client.load_table_from_dataframe(
    dataframe, 'machinelearning-240820.fibo.fibinha', job_config=job_config
)  # Make an API request.
job.result()  # Wait for the job to complete.

# %%
np.min(df.Momentum)
# Out:
# -8.98348752199331
